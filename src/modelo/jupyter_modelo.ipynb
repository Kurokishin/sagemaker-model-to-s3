# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("../dataframe/Hotel Reservations tratado.csv")

# %%
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %%
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
figura = plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x='label_avg_price_per_room', y='no_of_weekend_nights', data=df, palette='inferno')
plt.title('Gráfico 1')
# Out:
# Text(0.5, 1.0, 'Gráfico 1')

# %%
# treinamento modelo
data_treinamento = df.iloc[0:36000,:]
data_treinamento.shape
# Out:
# (36000, 19)

# %%
data_teste = df.iloc[36000:, :]
data_teste.shape
# Out:
# (275, 19)

# %%
x_teste = data_teste.iloc[:,:19].values
x_teste
# Out:
# array([['INN36001', 1, 0, ..., 1, 'Canceled', 3],
#        ['INN36002', 2, 0, ..., 0, 'Canceled', 1],
#        ['INN36003', 2, 0, ..., 2, 'Not_Canceled', 2],
#        ...,
#        ['INN36273', 2, 0, ..., 2, 'Not_Canceled', 2],
#        ['INN36274', 2, 0, ..., 0, 'Canceled', 2],
#        ['INN36275', 2, 0, ..., 0, 'Not_Canceled', 3]], dtype=object)

# %%
y_teste = data_teste.iloc[:0].values
y_teste
# Out:
# array([], shape=(0, 19), dtype=object)

# %%
data_treinamento.to_csv('../dataframe/Hotel Reservations train.csv', header = False, index = False)
data_teste.to_csv('../dataframe/Hotel Reservations teste.csv', header = False, index = False)
